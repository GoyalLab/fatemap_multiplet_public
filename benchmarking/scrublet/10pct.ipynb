# %%
import matplotlib.pyplot as plt
from scrublet_util import *
import os
import re

# %%
################################
#                              #
#       Input Parameters       #
#                              #
################################
root_dir = "/projects/p31666/zzhang/doublet-bchmk/data/fatemap_data"
out_dir = "/projects/p31666/zzhang/doublet-bchmk/final_sum"
save_root = "/projects/b1042/GoyalLab/zzhang/doublet_objects_sum/scrublet"
METHOD_ID = "scrublet"
root_bchmk_dataset = "/projects/p31666/zzhang/doublet-bchmk/data/bchmk_paper_real_data"
num_test = 1
doublet_rates_to_test = [0.05, 0.08, 0.1, 0.15, 0.2, 0.25]
ACT_DBL = 0.1


################################
#                              #
#             Main             #
#                              #
################################

def main(root_dir, METHOD_ID, out_dir):
    out_dfs = []
    out_stats = []
    
    all_detection_rates_file = os.path.join(out_dir, METHOD_ID, "stats", "all_detection_rates_{}.tsv".format(ACT_DBL))
    all_datasets_dirs = [os.path.join(root_dir, x) for x in next(os.walk(root_dir))[1]]

    for expected_doublet_rate in doublet_rates_to_test:
        print("INFO: Currently testing expected doublet rate:{}, actual doublet rate:{}".
              format(str(expected_doublet_rate), str(ACT_DBL)))
        for cur_dataset_dir in all_datasets_dirs:
            cur_out_df = run_scrublet_on_dataset(cur_dataset_dir, METHOD_ID, num_to_test=num_test,
                                                 exp_dbl=expected_doublet_rate, act_dbl=ACT_DBL, save_root = save_root)
            out_dfs.append(cur_out_df)
            cur_out_df["dbl_exp"] = expected_doublet_rate
            cur_out_df["dbl_act"] = ACT_DBL

    all_df = pd.concat(out_dfs)
    all_df.to_csv(all_detection_rates_file, sep="\t", index=False)
    return True


if __name__ == "__main__":
    main(root_dir, METHOD_ID, out_dir)
# Out:
# INFO: Currently testing expected doublet rate:0.05, actual doublet rate:0.1
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.10003096934035305
# INFO: Random stat is 81858
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 66.7%
# Elapsed time: 13.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 25196
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 26.7%
# Elapsed time: 15.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 13086
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 3.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.8%
# Elapsed time: 5.1 seconds
# INFO: summation doublets!
# 0.10005589714924538
# INFO: Random stat is 91661
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.9%
# Elapsed time: 5.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 71194
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.9%
# Elapsed time: 15.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 98063
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 20.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 36794
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 14.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 33999
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.9%
# Elapsed time: 15.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 1748
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 18.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 36838
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.4%
# Elapsed time: 12.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 76341
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 10928
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.2%
# Elapsed time: 9.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 18880
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.5%
# Elapsed time: 15.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 30045
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 15.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 30127
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.5%
# Elapsed time: 12.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 83617
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 19.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 84329
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 19.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 94776
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 20.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/Biorxiv
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 5302
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 1.4%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 90.9%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 2311
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 2.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 24396
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 7.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 79841
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 2.1%
# Estimated detectable doublet fraction = 2.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 75.0%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.10024449877750612
# INFO: Random stat is 47795
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 9.0%
# Estimated detectable doublet fraction = 12.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 75.5%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 28878
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 3.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM02
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 64367
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.0%
# Elapsed time: 15.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 38254
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.1%
# Elapsed time: 9.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 23701
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 32.4%
# Elapsed time: 12.8 seconds
# INFO: summation doublets!
# 0.10001524622655893
# INFO: Random stat is 2699
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 15.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/cellTag
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 90870
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 3.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 24.4%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 63313
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 8.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_reads
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 48714
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 5.8%
# Estimated detectable doublet fraction = 52.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.0%
# Elapsed time: 3.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 35914
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 5.6%
# Estimated detectable doublet fraction = 52.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.7%
# Elapsed time: 5.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM03
# INFO: summation doublets!
# 0.10002336994624912
# INFO: Random stat is 94345
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 9.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 3921
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.0%
# Elapsed time: 8.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/LARRY
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 94888
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 8.8%
# Estimated detectable doublet fraction = 52.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.6%
# Elapsed time: 7.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 75715
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 58.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.6%
# Elapsed time: 4.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 53852
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 50.0%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 32013
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 42.1%
# Elapsed time: 3.7 seconds
# INFO: summation doublets!
# 0.10010881392818281
# INFO: Random stat is 77528
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 3.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 3.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 42892
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 3.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 51.9%
# Elapsed time: 1.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 67935
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 3.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 42797
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.8%
# Elapsed time: 6.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 80066
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 6.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 68648
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.10
# Detected doublet rate = 14.2%
# Estimated detectable doublet fraction = 65.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.6%
# Elapsed time: 4.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 66438
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 51807
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 54.5%
# Elapsed time: 2.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 18886
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 3.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 32678
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.0%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 92190
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 3.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.8%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 23949
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 2.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 98234
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.2%
# Estimated detectable doublet fraction = 3.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 35.6%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 64994
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 3.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.5%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 12653
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 69.0%
# Elapsed time: 3.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 52976
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 2.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 51.9%
# Elapsed time: 0.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 93819
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 53.3%
# Elapsed time: 5.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 106
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 6.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 50161
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 42.9%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 1463
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.9%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 61064
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.0%
# Elapsed time: 5.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 6526
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 115.4%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 25069
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 7671
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.0%
# Elapsed time: 1.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 11672
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 62.1%
# Elapsed time: 2.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 90811
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.5%
# Elapsed time: 2.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 96101
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 5.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.0%
# Elapsed time: 1.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 23185
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 5.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 81271
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 14.3%
# Estimated detectable doublet fraction = 62.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.0%
# Elapsed time: 3.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 60226
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 17.8%
# Elapsed time: 5.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 65594
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.8%
# Elapsed time: 11.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 26670
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 9.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 26691
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 9.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 90214
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 4.9%
# Estimated detectable doublet fraction = 46.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.5%
# Elapsed time: 9.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 4297
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 5.1%
# Estimated detectable doublet fraction = 52.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.8%
# Elapsed time: 15.7 seconds
# INFO: summation doublets!
# 0.10005437737901034
# INFO: Random stat is 49976
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 5.5%
# Estimated detectable doublet fraction = 54.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.3%
# Elapsed time: 3.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 17317
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 5.5%
# Estimated detectable doublet fraction = 55.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.0%
# Elapsed time: 7.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 98360
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 4.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.1%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 76482
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.0%
# Elapsed time: 34.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 226
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 54.5%
# Elapsed time: 26.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 21086
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.2%
# Elapsed time: 12.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 59116
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.0%
# Elapsed time: 8.1 seconds
# INFO: summation doublets!
# 0.1000116157509583
# INFO: Random stat is 88915
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 23.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 62348
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 4.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.6%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.10013908205841446
# INFO: Random stat is 90764
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.4%
# Estimated detectable doublet fraction = 8.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 28849
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 4.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.6%
# Elapsed time: 3.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 45131
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 4.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.4%
# Elapsed time: 2.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 21050
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 27.2 seconds
# INFO: summation doublets!
# 0.10043668122270742
# INFO: Random stat is 28519
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 8.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.8%
# Elapsed time: 0.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 6701
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 2.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.0%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 88401
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 17.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 78587
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 2.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 0.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 17076
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 7.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 15825
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.0%
# Elapsed time: 2.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.10019646365422397
# INFO: Random stat is 93700
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 8.1%
# Estimated detectable doublet fraction = 50.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.1%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 62270
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 25.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.2%
# Elapsed time: 0.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 3690
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 7.7%
# Estimated detectable doublet fraction = 55.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.0%
# Elapsed time: 1.4 seconds
# INFO: Currently testing expected doublet rate:0.08, actual doublet rate:0.1
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.10003096934035305
# INFO: Random stat is 10409
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 5.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 94093
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 27.7%
# Elapsed time: 11.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 92865
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 3.5%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 15.1%
# Elapsed time: 5.1 seconds
# INFO: summation doublets!
# 0.10005589714924538
# INFO: Random stat is 56986
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 47.1%
# Elapsed time: 4.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 56717
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 6.7%
# Elapsed time: 12.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 92406
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 66904
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 12.5%
# Elapsed time: 10.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 39146
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 10.3%
# Elapsed time: 14.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 32157
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 27.3%
# Elapsed time: 12.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 88017
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 11.8%
# Elapsed time: 11.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 61245
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 0.0%
# Elapsed time: 15.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 91639
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 20.0%
# Elapsed time: 6.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 19724
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.65
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 14.3%
# Elapsed time: 12.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 42413
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# ...
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 21.4%
# Elapsed time: 15.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 55306
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 7.4%
# Estimated detectable doublet fraction = 42.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.3%
# Elapsed time: 22.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 79455
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 20.1%
# Estimated detectable doublet fraction = 75.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.8%
# Elapsed time: 14.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 80694
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 24.1%
# Estimated detectable doublet fraction = 48.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 49.2%
# Elapsed time: 15.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 95916
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.79
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.4%
# Elapsed time: 12.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 63521
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 7.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 13.6%
# Elapsed time: 9.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 90505
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.71
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 2.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 32.0%
# Elapsed time: 14.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 23313
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.71
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 2.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 25.0%
# Elapsed time: 15.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 99509
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.72
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 4.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.7%
# Elapsed time: 13.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 94285
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 7.6%
# Estimated detectable doublet fraction = 33.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 22.8%
# Elapsed time: 7.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 40417
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 25.0%
# Elapsed time: 3.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 85953
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.72
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 74.1%
# Elapsed time: 16.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 81297
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 9.1%
# Estimated detectable doublet fraction = 31.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.0%
# Elapsed time: 9.9 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 96065
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 21.9%
# Estimated detectable doublet fraction = 76.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.6%
# Elapsed time: 25.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 62401
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 13.1%
# Estimated detectable doublet fraction = 53.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.4%
# Elapsed time: 20.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 68165
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.75
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 2.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 27.4%
# Elapsed time: 9.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 56190
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.80
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 13.3%
# Elapsed time: 3.6 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 59141
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 7.8%
# Estimated detectable doublet fraction = 40.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 19.4%
# Elapsed time: 21.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 41700
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.70
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 60.0%
# Elapsed time: 12.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 79675
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.74
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 45.6%
# Elapsed time: 5.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 81603
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 11.4%
# Estimated detectable doublet fraction = 50.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 22.5%
# Elapsed time: 9.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 79755
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 11.5%
# Estimated detectable doublet fraction = 22.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 51.0%
# Elapsed time: 12.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 42798
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 14.7%
# Estimated detectable doublet fraction = 51.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.4%
# Elapsed time: 13.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 11864
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.70
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 6.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 16.1%
# Elapsed time: 3.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 398
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 14.7%
# Estimated detectable doublet fraction = 62.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 23.8%
# Elapsed time: 12.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 38227
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 17.7%
# Estimated detectable doublet fraction = 68.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.0%
# Elapsed time: 15.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 68087
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 4.7%
# Estimated detectable doublet fraction = 30.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.8%
# Elapsed time: 20.0 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 73861
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 12.7%
# Estimated detectable doublet fraction = 48.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.3%
# Elapsed time: 24.1 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 10120
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 10.6%
# Estimated detectable doublet fraction = 41.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 25.6%
# Elapsed time: 29.2 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 73557
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 6.7%
# Estimated detectable doublet fraction = 33.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 20.0%
# Elapsed time: 22.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 14123
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 6.1%
# Estimated detectable doublet fraction = 55.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 10.9%
# Elapsed time: 18.4 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 18706
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 6.6%
# Estimated detectable doublet fraction = 61.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 10.8%
# Elapsed time: 31.6 seconds
# INFO: summation doublets!
# 0.10005437737901034
# INFO: Random stat is 68995
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 6.9%
# Estimated detectable doublet fraction = 63.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 10.9%
# Elapsed time: 10.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 92790
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 26.3%
# Estimated detectable doublet fraction = 89.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.5%
# Elapsed time: 15.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 9392
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 5.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 20.8%
# Elapsed time: 5.8 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 20548
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 7.9%
# Estimated detectable doublet fraction = 44.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 18.0%
# Elapsed time: 60.5 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 89681
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 4.2%
# Estimated detectable doublet fraction = 29.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 14.3%
# Elapsed time: 39.7 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 12577
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 6.5%
# Estimated detectable doublet fraction = 48.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 13.3%
# Elapsed time: 25.3 seconds
# INFO: summation doublets!
# 0.1
# INFO: Random stat is 1559
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 8.4%
# Estimated detectable doublet fraction = 44.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 18.8%
# Elapsed time: 16.9 seconds
