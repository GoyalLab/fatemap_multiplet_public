# %%
import matplotlib.pyplot as plt
from scrublet_util import *
import os
import re

# %%
################################
#                              #
#       Input Parameters       #
#                              #
################################
root_dir = "/projects/p31666/zzhang/doublet-bchmk/data/fatemap_data"
out_dir = "/projects/p31666/zzhang/doublet-bchmk/final_sum"
save_root = "/projects/b1042/GoyalLab/zzhang/doublet_objects_sum/scrublet"
METHOD_ID = "scrublet"
root_bchmk_dataset = "/projects/p31666/zzhang/doublet-bchmk/data/bchmk_paper_real_data"
num_test = 1
doublet_rates_to_test = [0.05, 0.08, 0.1, 0.15, 0.2, 0.25]
ACT_DBL = 0.25


################################
#                              #
#             Main             #
#                              #
################################

def main(root_dir, METHOD_ID, out_dir):
    out_dfs = []
    out_stats = []
    
    all_detection_rates_file = os.path.join(out_dir, METHOD_ID, "stats", "all_detection_rates_{}.tsv".format(ACT_DBL))
    all_datasets_dirs = [os.path.join(root_dir, x) for x in next(os.walk(root_dir))[1]]
    for expected_doublet_rate in doublet_rates_to_test:
        print("INFO: Currently testing expected doublet rate:{}, actual doublet rate:{}".
              format(str(expected_doublet_rate), str(ACT_DBL)))
        for cur_dataset_dir in all_datasets_dirs:
            cur_out_df = run_scrublet_on_dataset(cur_dataset_dir, METHOD_ID, num_to_test=num_test,
                                                 exp_dbl=expected_doublet_rate, act_dbl=ACT_DBL, save_root = save_root)
            out_dfs.append(cur_out_df)
            cur_out_df["dbl_exp"] = expected_doublet_rate
            cur_out_df["dbl_act"] = ACT_DBL

    all_df = pd.concat(out_dfs)
    all_df.to_csv(all_detection_rates_file, sep="\t", index=False)
    return True


if __name__ == "__main__":
    main(root_dir, METHOD_ID, out_dir)
# Out:
# INFO: Currently testing expected doublet rate:0.05, actual doublet rate:0.25
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 21446
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 10.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 69301
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.0%
# Elapsed time: 16.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 41293
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 32.7%
# Elapsed time: 2.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 87251
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 53.3%
# Elapsed time: 4.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 88891
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.1%
# Elapsed time: 17.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 24541
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 83.3%
# Elapsed time: 18.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 36602
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 12.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 79339
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.5%
# Elapsed time: 11.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 74458
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.0%
# Elapsed time: 13.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 87160
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 11.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 83647
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 12.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 41967
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 9.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 59704
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 59206
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 11.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 26392
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.0%
# Elapsed time: 11.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 7484
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 16.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 85946
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.8%
# Elapsed time: 17.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 56831
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 15.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/Biorxiv
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 21079
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 2.2%
# Estimated detectable doublet fraction = 3.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 73.7%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 21156
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 44.4%
# Elapsed time: 3.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 5784
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 2.1%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 87.5%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 76772
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 100.0%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 22763
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 1.9%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 116.7%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 50676
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 1.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 54.5%
# Elapsed time: 2.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM02
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 21485
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 10805
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 44.4%
# Elapsed time: 8.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 55022
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 11.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 96928
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/cellTag
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 59474
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.5%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 2910
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 266.7%
# Elapsed time: 7.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_reads
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 99163
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 3.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.5%
# Elapsed time: 5.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 41674
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 4.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.7%
# Elapsed time: 2.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM03
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 96192
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.1%
# Elapsed time: 8.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 39280
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 45.5%
# Elapsed time: 9.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/LARRY
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 69937
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 5.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 20931
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.1%
# Elapsed time: 4.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 53020
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 38.5%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 68599
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.0%
# Elapsed time: 5.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 78249
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 57.1%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 99699
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 4.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 53.3%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 84573
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 6.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 47.1%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 199
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 6.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 22207
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 57.1%
# Elapsed time: 7.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 45955
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.1%
# Elapsed time: 4.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 71793
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 60.0%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 32626
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.2%
# Estimated detectable doublet fraction = 2.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 44.8%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 42656
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 2.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.1%
# Elapsed time: 0.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 48012
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 26.7%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 51979
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 2.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 85695
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.8%
# Estimated detectable doublet fraction = 2.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 78.3%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 92644
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 15316
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 58.8%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 63252
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 51.3%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 76699
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 2.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 110.0%
# Elapsed time: 0.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 49827
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 44.4%
# Elapsed time: 4.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 65733
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.1%
# Elapsed time: 5.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 44007
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 39.4%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 80621
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 44.4%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 70217
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 70.0%
# Elapsed time: 3.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 30366
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 100.0%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 6232
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 88.9%
# Elapsed time: 2.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 27220
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 2.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 34.8%
# Elapsed time: 0.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 90079
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 46.2%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 98021
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 5.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 47162
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 2.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 638
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 47.6%
# Elapsed time: 5.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 15450
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 3.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 26531
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 5.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 80997
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 50.0%
# Elapsed time: 10.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 11960
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.1%
# Elapsed time: 8.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 36008
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 4.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 76116
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 7.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 52664
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.08
# Detected doublet rate = 16.5%
# Estimated detectable doublet fraction = 70.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.5%
# Elapsed time: 12.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 75292
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.3%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 45022
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 5.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 67160
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 3.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 29.1%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 12738
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 32.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 78650
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 17.4%
# Elapsed time: 25.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 72412
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.8%
# Elapsed time: 10.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 13927
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 8.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 18520
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.8%
# Elapsed time: 19.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 37488
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 88.9%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 99840
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 5.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.0%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 7723
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 32.3%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 21050
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 64.0%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 79854
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 20.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 34375
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 11.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 86827
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 2.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 72590
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 14.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 59666
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 8.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 31.4%
# Elapsed time: 0.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 13460
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 46.2%
# Elapsed time: 4.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 40691
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.0%
# Elapsed time: 2.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 20622
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 2.5%
# Estimated detectable doublet fraction = 11.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.8%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 41708
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 1.8%
# Estimated detectable doublet fraction = 16.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.0%
# Elapsed time: 0.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 28720
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 2.1%
# Estimated detectable doublet fraction = 11.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 17.9%
# Elapsed time: 1.0 seconds
# INFO: Currently testing expected doublet rate:0.08, actual doublet rate:0.25
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 55893
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 37.3%
# Elapsed time: 6.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 21449
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 22.2%
# Elapsed time: 12.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 88049
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 2.2%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 43.1%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 98187
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 36.4%
# Elapsed time: 2.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 42045
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 20.0%
# Elapsed time: 10.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 30288
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 11.8%
# Elapsed time: 12.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 73386
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 25.8%
# Elapsed time: 11.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 79338
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 40.0%
# Elapsed time: 11.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 32327
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 14.3%
# Elapsed time: 10.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 12210
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 12.5%
# Elapsed time: 9.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 76498
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 43.5%
# Elapsed time: 11.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 17415
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 8.2%
# Elapsed time: 6.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 6230
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 20.0%
# Elapsed time: 14.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 82586
# Preprocessing...
# ...
# 0.25
# INFO: Random stat is 6233
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 14.2%
# Estimated detectable doublet fraction = 31.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 45.6%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 39682
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 23.8%
# Estimated detectable doublet fraction = 60.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 39.4%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 26481
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.70
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 3.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 35.7%
# Elapsed time: 0.3 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 18086
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 31.8%
# Estimated detectable doublet fraction = 79.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 40.2%
# Elapsed time: 2.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 35711
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 33.4%
# Estimated detectable doublet fraction = 82.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 40.3%
# Elapsed time: 2.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 29540
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 10.7%
# Estimated detectable doublet fraction = 40.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.5%
# Elapsed time: 3.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 18435
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 4.2%
# Estimated detectable doublet fraction = 17.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.1%
# Elapsed time: 7.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 86202
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 6.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 33805
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 11.7%
# Estimated detectable doublet fraction = 39.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.8%
# Elapsed time: 4.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 26611
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 23.0%
# Estimated detectable doublet fraction = 76.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 30.2%
# Elapsed time: 8.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 50380
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 78.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 25.2%
# Elapsed time: 10.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 67885
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 31.5%
# Estimated detectable doublet fraction = 86.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 36.6%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 82460
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 37.3%
# Estimated detectable doublet fraction = 90.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 41.2%
# Elapsed time: 5.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 50911
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.75
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.3%
# Elapsed time: 1.2 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 54813
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 10.8%
# Estimated detectable doublet fraction = 43.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.7%
# Elapsed time: 50.9 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 86615
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 9.7%
# Estimated detectable doublet fraction = 42.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 22.7%
# Elapsed time: 41.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 38118
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 10.2%
# Estimated detectable doublet fraction = 46.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 21.9%
# Elapsed time: 18.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 1077
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 13.6%
# Estimated detectable doublet fraction = 48.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.1%
# Elapsed time: 21.4 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 86181
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 38.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 71296
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 10.2%
# Estimated detectable doublet fraction = 41.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.8%
# Elapsed time: 13.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 36586
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 19.1%
# Estimated detectable doublet fraction = 59.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 32.0%
# Elapsed time: 10.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 72456
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 5.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 21.1%
# Elapsed time: 9.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 67312
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 42.4%
# Elapsed time: 6.0 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 22448
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 11.0%
# Estimated detectable doublet fraction = 44.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.5%
# Elapsed time: 37.8 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 99684
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 3.4%
# Estimated detectable doublet fraction = 8.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 40.0%
# Elapsed time: 4.1 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 50632
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.72
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 3.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 14.0%
# Elapsed time: 12.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 94243
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 11.4%
# Estimated detectable doublet fraction = 47.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 23.9%
# Elapsed time: 37.5 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 86168
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 5.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 51.4%
# Elapsed time: 11.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 26359
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 15.0%
# Estimated detectable doublet fraction = 39.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 37.8%
# Elapsed time: 19.7 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 98564
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.78
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 20.0%
# Elapsed time: 8.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 48991
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 28.3%
# Estimated detectable doublet fraction = 77.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 36.6%
# Elapsed time: 6.6 seconds
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 7489
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 27.2%
# Estimated detectable doublet fraction = 68.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 39.5%
# Elapsed time: 7.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.25
# INFO: Random stat is 7538
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 15.6%
# Estimated detectable doublet fraction = 62.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.9%
# Elapsed time: 4.9 seconds
