# %%
import matplotlib.pyplot as plt
from scrublet_util import *
import os
import re
import random

# %%
################################
#                              #
#       Input Parameters       #
#                              #
################################
root_dir = "/projects/p31666/zzhang/doublet-bchmk/data/fatemap_data"
out_dir = "/projects/p31666/zzhang/doublet-bchmk/final_sum"
save_root = "/projects/b1042/GoyalLab/zzhang/doublet_objects_sum/scrublet"
METHOD_ID = "scrublet"
root_bchmk_dataset = "/projects/p31666/zzhang/doublet-bchmk/data/bchmk_paper_real_data"
num_test = 1
doublet_rates_to_test = [0.05, 0.08, 0.1, 0.15, 0.2, 0.25]
ACT_DBL = 0.05


################################
#                              #
#             Main             #
#                              #
################################

def main(root_dir, METHOD_ID, out_dir):
    out_dfs = []
    out_stats = []
    all_detection_rates_file = os.path.join(out_dir, METHOD_ID, "stats", "all_detection_rates_{}.tsv".format(ACT_DBL))
    
    all_datasets_dirs = [os.path.join(root_dir, x) for x in next(os.walk(root_dir))[1]]
    
    for expected_doublet_rate in doublet_rates_to_test:
        print("INFO: Currently testing expected doublet rate:{}, actual doublet rate:{}".
              format(str(expected_doublet_rate), str(ACT_DBL)))
        for cur_dataset_dir in all_datasets_dirs:
            cur_out_df = run_scrublet_on_dataset(cur_dataset_dir, METHOD_ID, num_to_test=num_test,
                                                 exp_dbl=expected_doublet_rate, act_dbl=ACT_DBL, save_root = save_root)
            out_dfs.append(cur_out_df)
            cur_out_df["dbl_exp"] = expected_doublet_rate
            cur_out_df["dbl_act"] = ACT_DBL

    all_df = pd.concat(out_dfs)
    all_df.to_csv(all_detection_rates_file, sep="\t", index=False)
    return True


if __name__ == "__main__":
    main(root_dir, METHOD_ID, out_dir)
# Out:
# INFO: Currently testing expected doublet rate:0.05, actual doublet rate:0.05
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.050014797277300974
# INFO: Random stat is 92603
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.6%
# Elapsed time: 8.9 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 84016
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.0%
# Elapsed time: 15.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 52917
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 3.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.9%
# Elapsed time: 3.6 seconds
# INFO: summation doublets!
# 0.05002689618074233
# INFO: Random stat is 48011
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.3%
# Elapsed time: 5.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.05000762311327946
# INFO: Random stat is 16806
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.3%
# Elapsed time: 16.2 seconds
# INFO: summation doublets!
# 0.050007988496564945
# INFO: Random stat is 65675
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 4.7%
# Elapsed time: 21.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 36619
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.9%
# Elapsed time: 16.3 seconds
# INFO: summation doublets!
# 0.050007741136398824
# INFO: Random stat is 98548
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 4.4%
# Elapsed time: 15.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.05000817126981533
# INFO: Random stat is 55748
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 16.5 seconds
# INFO: summation doublets!
# 0.05001046243984097
# INFO: Random stat is 17897
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 2.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 2.4%
# Elapsed time: 16.7 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 56578
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.7%
# Elapsed time: 14.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 22636
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.0%
# Elapsed time: 9.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.05001116320607278
# INFO: Random stat is 24136
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.9%
# Elapsed time: 16.8 seconds
# INFO: summation doublets!
# 0.05001012350678275
# INFO: Random stat is 45493
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.1%
# Elapsed time: 15.0 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 29782
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.0%
# Elapsed time: 13.4 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 27750
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 22.8 seconds
# INFO: summation doublets!
# 0.050009471490812654
# INFO: Random stat is 70648
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 21.7 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 91595
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.1%
# Elapsed time: 19.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/Biorxiv
# INFO: summation doublets!
# 0.05013927576601671
# INFO: Random stat is 22304
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 3.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.3%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 23395
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.5%
# Elapsed time: 3.8 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 72863
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:253: RuntimeWarning: invalid value encountered in sqrt
#   CV_eff = np.sqrt((1+a)*(1+b) - 1);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 1.2%
# Estimated detectable doublet fraction = 6.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 1.0 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 6521
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 63.2%
# Elapsed time: 2.4 seconds
# INFO: summation doublets!
# 0.050119331742243436
# INFO: Random stat is 56272
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 3.6%
# Estimated detectable doublet fraction = 7.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 50.8%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.050059594755661505
# INFO: Random stat is 39995
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 3.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 54.8%
# Elapsed time: 2.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM02
# INFO: summation doublets!
# 0.05000853387950162
# INFO: Random stat is 97789
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 3.1%
# Elapsed time: 13.7 seconds
# INFO: summation doublets!
# 0.05001116320607278
# INFO: Random stat is 46873
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 10.6 seconds
# INFO: summation doublets!
# 0.050009192866335726
# INFO: Random stat is 9921
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 10.5 seconds
# INFO: summation doublets!
# 0.05000728969237498
# INFO: Random stat is 51863
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 13.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/cellTag
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 63572
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 4.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.1%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.05001323101349563
# INFO: Random stat is 77031
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.4%
# Elapsed time: 8.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_reads
# INFO: summation doublets!
# 0.050049067713444556
# INFO: Random stat is 97804
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 3.1%
# Estimated detectable doublet fraction = 53.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.8%
# Elapsed time: 4.5 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 86255
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 3.0%
# Estimated detectable doublet fraction = 37.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.9%
# Elapsed time: 2.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM03
# INFO: summation doublets!
# 0.05001116320607278
# INFO: Random stat is 8685
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.4%
# Elapsed time: 9.7 seconds
# INFO: summation doublets!
# 0.050012758356723655
# INFO: Random stat is 50524
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 10.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/LARRY
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 70863
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 6.6%
# Estimated detectable doublet fraction = 51.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.8%
# Elapsed time: 4.5 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 91410
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.8%
# Elapsed time: 4.8 seconds
# INFO: summation doublets!
# 0.05006954102920723
# INFO: Random stat is 24005
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.4%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 34.5%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.050020333468889795
# INFO: Random stat is 71482
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 3.7 seconds
# INFO: summation doublets!
# 0.05005213764337852
# INFO: Random stat is 46578
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 2.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.6%
# Elapsed time: 3.4 seconds
# INFO: summation doublets!
# 0.05013927576601671
# INFO: Random stat is 55231
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 3.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 0.3 seconds
# INFO: summation doublets!
# 0.050078247261345854
# INFO: Random stat is 54414
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 39.2%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.05001524855138762
# INFO: Random stat is 42520
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.5%
# Elapsed time: 6.9 seconds
# INFO: summation doublets!
# 0.05001168497312456
# INFO: Random stat is 4072
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.4%
# Elapsed time: 4.3 seconds
# INFO: summation doublets!
# 0.05002213368747233
# INFO: Random stat is 52791
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 2.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.0%
# Elapsed time: 2.9 seconds
# INFO: summation doublets!
# 0.050033806626098715
# INFO: Random stat is 85695
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 3.0 seconds
# INFO: summation doublets!
# 0.05003971405877681
# INFO: Random stat is 40547
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 50.0%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 39719
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 5.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 4.9%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.05010438413361169
# INFO: Random stat is 50575
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.7%
# Estimated detectable doublet fraction = 5.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 31.4%
# Elapsed time: 2.7 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 30365
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 5.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.05004314063848145
# INFO: Random stat is 58790
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 42.9%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 16766
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 5.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.0%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 47918
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 3.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.1%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 92927
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 52.2%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.05008635578583765
# INFO: Random stat is 84587
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 8.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.0%
# Elapsed time: 2.8 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 35225
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.9%
# Elapsed time: 5.9 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 73577
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 24.2%
# Elapsed time: 6.3 seconds
# INFO: summation doublets!
# 0.050030506406345335
# INFO: Random stat is 52559
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.0%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 74436
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 36.4%
# Elapsed time: 2.8 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 17606
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 21.7%
# Elapsed time: 2.9 seconds
# INFO: summation doublets!
# 0.05004633920296571
# INFO: Random stat is 21802
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 120.0%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.050031665611146296
# INFO: Random stat is 6672
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.0%
# Elapsed time: 1.2 seconds
# INFO: summation doublets!
# 0.050073637702503684
# INFO: Random stat is 46890
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 5.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.5%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.05004314063848145
# INFO: Random stat is 15346
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 100.0%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 87130
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 2.8 seconds
# INFO: summation doublets!
# 0.05009633911368015
# INFO: Random stat is 24503
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.2%
# Estimated detectable doublet fraction = 6.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 0.5 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 70637
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.1%
# Elapsed time: 3.2 seconds
# INFO: summation doublets!
# 0.05001894657067071
# INFO: Random stat is 60474
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.0%
# Elapsed time: 2.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.050016784155756965
# INFO: Random stat is 29400
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 3.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 75289
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 11.6 seconds
# INFO: summation doublets!
# 0.050010824853864475
# INFO: Random stat is 43704
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 10.7 seconds
# INFO: summation doublets!
# 0.05001302422505861
# INFO: Random stat is 53320
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 9.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.05001381597126278
# INFO: Random stat is 74463
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 42.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.1%
# Elapsed time: 8.7 seconds
# INFO: summation doublets!
# 0.05000827951647624
# INFO: Random stat is 21192
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 2.5%
# Estimated detectable doublet fraction = 46.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.3%
# Elapsed time: 12.7 seconds
# INFO: summation doublets!
# 0.05002605523710266
# INFO: Random stat is 41794
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 2.5%
# Estimated detectable doublet fraction = 42.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.8%
# Elapsed time: 1.8 seconds
# INFO: summation doublets!
# 0.05001420858198352
# INFO: Random stat is 2478
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 39.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.8%
# Elapsed time: 5.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 38515
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 1.4%
# Estimated detectable doublet fraction = 7.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.4%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.050003840540748135
# INFO: Random stat is 48167
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.0%
# Elapsed time: 41.6 seconds
# INFO: summation doublets!
# 0.05000508181725785
# INFO: Random stat is 67090
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 30.0 seconds
# INFO: summation doublets!
# 0.050009471490812654
# INFO: Random stat is 12179
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.8%
# Elapsed time: 15.3 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 74429
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.2%
# Elapsed time: 6.8 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 24793
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 23.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 72091
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 10.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.1%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.05006765899864682
# INFO: Random stat is 82273
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 10.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.8%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.05004812319538017
# INFO: Random stat is 9086
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 5.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.6%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.05004633920296571
# INFO: Random stat is 29040
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 5.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.4%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.05000481741978996
# INFO: Random stat is 10371
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.63
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 25.0 seconds
# INFO: summation doublets!
# 0.0502092050209205
# INFO: Random stat is 66276
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 9.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.9%
# Elapsed time: 0.3 seconds
# INFO: summation doublets!
# 0.05006954102920723
# INFO: Random stat is 81005
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 7.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.3%
# Elapsed time: 2.1 seconds
# INFO: summation doublets!
# 0.050007554011179935
# INFO: Random stat is 99131
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.8%
# Elapsed time: 17.6 seconds
# INFO: summation doublets!
# 0.05006954102920723
# INFO: Random stat is 75284
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.8%
# Estimated detectable doublet fraction = 7.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.2%
# Elapsed time: 1.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 88597
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.0%
# Elapsed time: 7.2 seconds
# INFO: summation doublets!
# 0.05004101722723544
# INFO: Random stat is 92234
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 3.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.05009633911368015
# INFO: Random stat is 3518
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 6.2%
# Estimated detectable doublet fraction = 50.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.1%
# Elapsed time: 2.8 seconds
# INFO: summation doublets!
# 0.05019305019305019
# INFO: Random stat is 8204
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 1.9%
# Estimated detectable doublet fraction = 35.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.4%
# Elapsed time: 0.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 77415
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 3.5%
# Estimated detectable doublet fraction = 49.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.1%
# Elapsed time: 2.7 seconds
# INFO: Currently testing expected doublet rate:0.08, actual doublet rate:0.05
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.050014797277300974
# INFO: Random stat is 94682
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 36.8%
# Elapsed time: 5.5 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 489
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 0.0%
# Elapsed time: 11.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 3175
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 2.5%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 20.0%
# Elapsed time: 2.9 seconds
# INFO: summation doublets!
# 0.05002689618074233
# INFO: Random stat is 25347
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 15.8%
# Elapsed time: 4.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.05000762311327946
# INFO: Random stat is 95256
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 11.4%
# Elapsed time: 13.8 seconds
# INFO: summation doublets!
# 0.050007988496564945
# INFO: Random stat is 7470
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 9.4%
# Elapsed time: 14.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 57526
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 9.9%
# Elapsed time: 11.8 seconds
# INFO: summation doublets!
# 0.050007741136398824
# INFO: Random stat is 76251
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 2.4%
# Elapsed time: 13.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.05000817126981533
# INFO: Random stat is 41256
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 0.0%
# Elapsed time: 14.4 seconds
# INFO: summation doublets!
# 0.05001046243984097
# INFO: Random stat is 80783
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.65
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 3.5%
# Elapsed time: 14.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 51130
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 2.2%
# Elapsed time: 14.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 90433
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 3.4%
# Elapsed time: 11.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# ...
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.75
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.6%
# Elapsed time: 14.1 seconds
# INFO: summation doublets!
# 0.050073637702503684
# INFO: Random stat is 65535
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 11.6%
# Estimated detectable doublet fraction = 52.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 22.3%
# Elapsed time: 7.9 seconds
# INFO: summation doublets!
# 0.05004314063848145
# INFO: Random stat is 93736
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.72
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 2.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 54.0%
# Elapsed time: 5.1 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 8227
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.63
# Detected doublet rate = 2.5%
# Estimated detectable doublet fraction = 20.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 12.3%
# Elapsed time: 8.5 seconds
# INFO: summation doublets!
# 0.05009633911368015
# INFO: Random stat is 77291
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 16.0%
# Estimated detectable doublet fraction = 60.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.3%
# Elapsed time: 8.9 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 23799
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 21.7%
# Estimated detectable doublet fraction = 75.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.8%
# Elapsed time: 9.1 seconds
# INFO: summation doublets!
# 0.05001894657067071
# INFO: Random stat is 75886
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 11.5%
# Estimated detectable doublet fraction = 57.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 20.0%
# Elapsed time: 7.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.050016784155756965
# INFO: Random stat is 63189
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 7.2%
# Estimated detectable doublet fraction = 45.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.7%
# Elapsed time: 18.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 39852
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 67.7%
# Estimated detectable doublet fraction = 94.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 71.7%
# Elapsed time: 23.1 seconds
# INFO: summation doublets!
# 0.050010824853864475
# INFO: Random stat is 54814
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 28.1%
# Estimated detectable doublet fraction = 70.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 39.7%
# Elapsed time: 27.5 seconds
# INFO: summation doublets!
# 0.05001302422505861
# INFO: Random stat is 24801
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 5.5%
# Estimated detectable doublet fraction = 34.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.9%
# Elapsed time: 23.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.05001381597126278
# INFO: Random stat is 52053
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 46.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 6.3%
# Elapsed time: 19.5 seconds
# INFO: summation doublets!
# 0.05000827951647624
# INFO: Random stat is 56652
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 3.3%
# Estimated detectable doublet fraction = 54.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 6.0%
# Elapsed time: 24.3 seconds
# INFO: summation doublets!
# 0.05002605523710266
# INFO: Random stat is 90704
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 3.5%
# Estimated detectable doublet fraction = 57.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 6.1%
# Elapsed time: 10.6 seconds
# INFO: summation doublets!
# 0.05001420858198352
# INFO: Random stat is 10496
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 3.5%
# Estimated detectable doublet fraction = 60.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 5.7%
# Elapsed time: 16.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 96226
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 7.1%
# Estimated detectable doublet fraction = 44.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.9%
# Elapsed time: 9.3 seconds
# INFO: summation doublets!
# 0.050003840540748135
# INFO: Random stat is 19501
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 6.0%
# Estimated detectable doublet fraction = 42.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 14.2%
# Elapsed time: 70.2 seconds
# INFO: summation doublets!
# 0.05000508181725785
# INFO: Random stat is 97832
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 4.2%
# Estimated detectable doublet fraction = 36.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 11.6%
# Elapsed time: 43.8 seconds
# INFO: summation doublets!
# 0.050009471490812654
# INFO: Random stat is 72396
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.72
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 20.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 6.2%
# Elapsed time: 21.5 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 25311
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 9.8%
# Estimated detectable doublet fraction = 55.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.6%
# Elapsed time: 16.6 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 28193
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 13.7%
# Estimated detectable doublet fraction = 69.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 19.6%
# Elapsed time: 43.4 seconds
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 47435
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.63
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 31.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 9.1%
# Elapsed time: 15.0 seconds
# INFO: summation doublets!
# 0.05006765899864682
# INFO: Random stat is 67921
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 4.2%
# Estimated detectable doublet fraction = 42.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 9.8%
# Elapsed time: 7.2 seconds
# INFO: summation doublets!
# 0.05004812319538017
# INFO: Random stat is 56369
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 6.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 4.4%
# Elapsed time: 9.7 seconds
# INFO: summation doublets!
# 0.05004633920296571
# INFO: Random stat is 65364
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 5.2%
# Estimated detectable doublet fraction = 44.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 11.7%
# Elapsed time: 6.5 seconds
# INFO: summation doublets!
# 0.05000481741978996
# INFO: Random stat is 68894
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 9.1%
# Estimated detectable doublet fraction = 48.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 18.8%
# Elapsed time: 38.5 seconds
# INFO: summation doublets!
# 0.0502092050209205
# INFO: Random stat is 47009
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 14.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 8.5%
# Elapsed time: 7.8 seconds
# INFO: summation doublets!
# 0.05006954102920723
# INFO: Random stat is 56692
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 12.0%
# Estimated detectable doublet fraction = 48.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.6%
# Elapsed time: 15.2 seconds
# INFO: summation doublets!
# 0.050007554011179935
# INFO: Random stat is 94059
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 8.8%
# Estimated detectable doublet fraction = 54.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 16.1%
# Elapsed time: 37.5 seconds
# INFO: summation doublets!
# 0.05006954102920723
# INFO: Random stat is 70378
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 16.3%
# Estimated detectable doublet fraction = 61.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.6%
# Elapsed time: 12.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.05
# INFO: Random stat is 45767
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 23.8%
# Estimated detectable doublet fraction = 58.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 40.9%
# Elapsed time: 14.0 seconds
# INFO: summation doublets!
# 0.05004101722723544
# INFO: Random stat is 87651
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 7.5%
# Estimated detectable doublet fraction = 30.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.7%
# Elapsed time: 11.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis

# %%
all_detection_rates_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-74453e552d04> in <module>
# ----> 1 all_detection_rates_file
#
# NameError: name 'all_detection_rates_file' is not defined
