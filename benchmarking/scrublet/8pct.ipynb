# %%
import matplotlib.pyplot as plt
from scrublet_util import *
import os
import re

# %%
################################
#                              #
#       Input Parameters       #
#                              #
################################
root_dir = "/projects/p31666/zzhang/doublet-bchmk/data/fatemap_data"
out_dir = "/projects/p31666/zzhang/doublet-bchmk/final_sum"
save_root = "/projects/b1042/GoyalLab/zzhang/doublet_objects_sum/scrublet"
METHOD_ID = "scrublet"
root_bchmk_dataset = "/projects/p31666/zzhang/doublet-bchmk/data/bchmk_paper_real_data"
num_test = 1
doublet_rates_to_test = [0.05, 0.08, 0.1, 0.15, 0.2, 0.25]
ACT_DBL = 0.08


################################
#                              #
#             Main             #
#                              #
################################

def main(root_dir, METHOD_ID, out_dir):
    out_dfs = []
    out_stats = []
    
    all_detection_rates_file = os.path.join(out_dir, METHOD_ID, "stats", "all_detection_rates_{}.tsv".format(ACT_DBL))
    all_datasets_dirs = [os.path.join(root_dir, x) for x in next(os.walk(root_dir))[1]]
    for expected_doublet_rate in doublet_rates_to_test:
        print("INFO: Currently testing expected doublet rate:{}, actual doublet rate:{}".
              format(str(expected_doublet_rate), str(ACT_DBL)))
        for cur_dataset_dir in all_datasets_dirs:
            print(cur_dataset_dir)
            cur_out_df = run_scrublet_on_dataset(cur_dataset_dir, METHOD_ID, num_to_test=num_test,
                                                 exp_dbl=expected_doublet_rate, act_dbl=ACT_DBL, save_root = save_root)
            out_dfs.append(cur_out_df)
            cur_out_df["dbl_exp"] = expected_doublet_rate
            cur_out_df["dbl_act"] = ACT_DBL

    all_df = pd.concat(out_dfs)
    all_df.to_csv(all_detection_rates_file, sep="\t", index=False)
    return True


if __name__ == "__main__":
    main(root_dir, METHOD_ID, out_dir)
# Out:
# INFO: Currently testing expected doublet rate:0.05, actual doublet rate:0.08
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.0800121691512017
# INFO: Random stat is 79618
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.6%
# Elapsed time: 8.3 seconds
# INFO: summation doublets!
# 0.08000654450261781
# INFO: Random stat is 8189
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 18.1 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.08002936857562408
# INFO: Random stat is 8085
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.7%
# Elapsed time: 2.9 seconds
# INFO: summation doublets!
# 0.0800438596491228
# INFO: Random stat is 54375
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 3.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.8%
# Elapsed time: 4.7 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.08000626272115234
# INFO: Random stat is 63614
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.3%
# Elapsed time: 14.4 seconds
# INFO: summation doublets!
# 0.08000657138163299
# INFO: Random stat is 17524
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.1%
# Elapsed time: 15.3 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 86594
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.8%
# Elapsed time: 10.6 seconds
# INFO: summation doublets!
# 0.08000636233497693
# INFO: Random stat is 41845
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.1%
# Elapsed time: 14.9 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 10817
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 50.0%
# Elapsed time: 16.4 seconds
# INFO: summation doublets!
# 0.08000858000858001
# INFO: Random stat is 823
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 4.0%
# Elapsed time: 14.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 72527
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 2.5%
# Elapsed time: 13.6 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 69968
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 9.1 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.08000917010545622
# INFO: Random stat is 57073
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.9%
# Elapsed time: 13.9 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 36957
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 13.6 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 85593
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.3%
# Elapsed time: 14.8 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 90248
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 19.8 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 28222
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 17.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 81630
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 21.6 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/Biorxiv
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/Biorxiv
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 2669
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 1.7%
# Estimated detectable doublet fraction = 1.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 109.1%
# Elapsed time: 0.5 seconds
# INFO: summation doublets!
# 0.08005427408412483
# INFO: Random stat is 14318
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 80.0%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.08010335917312661
# INFO: Random stat is 16798
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 7.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 34.5%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.08006814310051108
# INFO: Random stat is 99855
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 111.1%
# Elapsed time: 4.5 seconds
# INFO: summation doublets!
# 0.08009708737864078
# INFO: Random stat is 50435
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 2.7%
# Estimated detectable doublet fraction = 6.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 38.6%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.08004926108374384
# INFO: Random stat is 42651
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 26.1%
# Elapsed time: 2.2 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM02
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM02
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 80571
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.1%
# Elapsed time: 15.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 87470
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 9.1 seconds
# INFO: summation doublets!
# 0.08000756572725554
# INFO: Random stat is 38017
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 13.1 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 18780
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 36.4%
# Elapsed time: 14.9 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/cellTag
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/cellTag
# INFO: summation doublets!
# 0.08002936857562408
# INFO: Random stat is 2201
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.9%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 11649
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 10.5 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_reads
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_reads
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 29848
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 1.2%
# Estimated detectable doublet fraction = 19.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.2%
# Elapsed time: 5.9 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 89002
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 4.7%
# Estimated detectable doublet fraction = 49.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.4%
# Elapsed time: 3.1 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM03
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM03
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 11102
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.6%
# Elapsed time: 11.9 seconds
# INFO: summation doublets!
# 0.08001049317943337
# INFO: Random stat is 12470
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 9.8 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/LARRY
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/LARRY
# INFO: summation doublets!
# 0.08001306335728282
# INFO: Random stat is 98011
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 8.5%
# Estimated detectable doublet fraction = 55.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 3.9 seconds
# INFO: summation doublets!
# 0.08001285347043702
# INFO: Random stat is 49037
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.8%
# Elapsed time: 3.7 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 37903
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 41.7%
# Elapsed time: 1.8 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 70866
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.9%
# Elapsed time: 6.7 seconds
# INFO: summation doublets!
# 0.08004268943436499
# INFO: Random stat is 28838
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.4%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 3952
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 5.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 41.0%
# Elapsed time: 0.6 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 44449
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 3.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 36.4%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 81411
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.8%
# Elapsed time: 4.8 seconds
# INFO: summation doublets!
# 0.08000961076405574
# INFO: Random stat is 368
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.3%
# Elapsed time: 6.5 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 99270
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.7%
# Elapsed time: 2.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 36606
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 1.0 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 19432
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.6%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.08010335917312661
# INFO: Random stat is 60875
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 1.8%
# Estimated detectable doublet fraction = 4.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 41.2%
# Elapsed time: 1.0 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 37941
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.0%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.08008213552361396
# INFO: Random stat is 62297
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 2.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 45.5%
# Elapsed time: 1.7 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 23480
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 50.0%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.08005822416302766
# INFO: Random stat is 34997
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 1.2%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 55.2%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 56112
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.6%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.08002936857562408
# INFO: Random stat is 95366
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 76.9%
# Elapsed time: 1.0 seconds
# INFO: summation doublets!
# 0.0800711743772242
# INFO: Random stat is 69978
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 3.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.8%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 26603
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.1%
# Elapsed time: 3.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 24217
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.8%
# Elapsed time: 6.9 seconds
# INFO: summation doublets!
# 0.0800252047889099
# INFO: Random stat is 99216
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.08003048780487805
# INFO: Random stat is 26012
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 32.3%
# Elapsed time: 3.3 seconds
# INFO: summation doublets!
# 0.08001245330012453
# INFO: Random stat is 80568
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 3.2 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 36996
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 80.0%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 39370
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 26.7%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.08006042296072508
# INFO: Random stat is 44357
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 4.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.3%
# Elapsed time: 3.0 seconds
# INFO: summation doublets!
# 0.08003518029903255
# INFO: Random stat is 94150
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 2.4%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 93.1%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 74328
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.3%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.080078125
# INFO: Random stat is 94725
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 6.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.4%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.08001245330012453
# INFO: Random stat is 18925
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 5.6 seconds
# INFO: summation doublets!
# 0.08001561280249805
# INFO: Random stat is 61988
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 3.9 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 54512
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 3.2%
# Elapsed time: 6.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 78687
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.3%
# Elapsed time: 12.8 seconds
# INFO: summation doublets!
# 0.08000891464229998
# INFO: Random stat is 52975
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 17.1%
# Elapsed time: 8.9 seconds
# INFO: summation doublets!
# 0.08001070377308
# INFO: Random stat is 27277
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 8.7 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.0800113895216401
# INFO: Random stat is 46053
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 4.0%
# Estimated detectable doublet fraction = 45.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.7%
# Elapsed time: 9.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 46228
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 4.2%
# Estimated detectable doublet fraction = 52.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.1%
# Elapsed time: 15.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 33290
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 4.1%
# Estimated detectable doublet fraction = 50.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.1%
# Elapsed time: 3.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 19306
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 4.3%
# Estimated detectable doublet fraction = 50.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.4%
# Elapsed time: 5.6 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 99341
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.08000315905860053
# INFO: Random stat is 74671
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.7%
# Elapsed time: 36.1 seconds
# INFO: summation doublets!
# 0.08000418322526669
# INFO: Random stat is 27871
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.5%
# Elapsed time: 26.5 seconds
# INFO: summation doublets!
# 0.08000778664590227
# INFO: Random stat is 37847
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 13.7 seconds
# INFO: summation doublets!
# 0.08001207729468598
# INFO: Random stat is 39380
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.0%
# Elapsed time: 9.4 seconds
# INFO: summation doublets!
# 0.08000456516776991
# INFO: Random stat is 14741
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 23.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 7763
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 5.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.2%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 30830
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 10.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.7%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 38175
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 5.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.0%
# Elapsed time: 3.9 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 1794
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.5%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.08000396550014871
# INFO: Random stat is 56950
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 28.0 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 89859
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 2.7%
# Estimated detectable doublet fraction = 9.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.3%
# Elapsed time: 0.5 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 21298
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 32.4%
# Elapsed time: 2.7 seconds
# INFO: summation doublets!
# 0.08000621407487961
# INFO: Random stat is 66908
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.8%
# Elapsed time: 17.4 seconds
# INFO: summation doublets!
# 0.0800561797752809
# INFO: Random stat is 55507
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 2.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 42.9%
# Elapsed time: 1.6 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.08001397624039133
# INFO: Random stat is 96445
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 7.6 seconds
# INFO: summation doublets!
# 0.08003369839932603
# INFO: Random stat is 64851
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.0%
# Elapsed time: 3.8 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.080078125
# INFO: Random stat is 99953
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 7.4%
# Estimated detectable doublet fraction = 53.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.9%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.08015267175572519
# INFO: Random stat is 39122
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 32.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 4.7%
# Elapsed time: 0.6 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.08010335917312661
# INFO: Random stat is 1534
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 4.4%
# Estimated detectable doublet fraction = 48.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.1%
# Elapsed time: 1.7 seconds
# INFO: Currently testing expected doublet rate:0.08, actual doublet rate:0.08
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.0800121691512017
# INFO: Random stat is 47651
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 15.4%
# Elapsed time: 6.4 seconds
# INFO: summation doublets!
# 0.08000654450261781
# INFO: Random stat is 486
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 17.6%
# Elapsed time: 13.8 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.08002936857562408
# INFO: Random stat is 99599
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 4.2%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 7.0%
# Elapsed time: 1.8 seconds
# INFO: summation doublets!
# 0.0800438596491228
# INFO: Random stat is 75209
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 30.8%
# Elapsed time: 4.1 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.08000626272115234
# INFO: Random stat is 30655
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 9.7%
# Estimated detectable doublet fraction = 56.8%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 17.1%
# Elapsed time: 15.2 seconds
# INFO: summation doublets!
# 0.08000657138163299
# INFO: Random stat is 10581
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 5.3%
# Elapsed time: 14.6 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 59458
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 9.7%
# Elapsed time: 14.0 seconds
# INFO: summation doublets!
# 0.08000636233497693
# INFO: Random stat is 94883
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 5.9%
# Elapsed time: 13.8 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 91504
# Preprocessing...
# Simulating doublets...
# ...
# INFO: summation doublets!
# 0.080078125
# INFO: Random stat is 47509
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 24.6%
# Estimated detectable doublet fraction = 66.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 37.2%
# Elapsed time: 16.1 seconds
# INFO: summation doublets!
# 0.08001245330012453
# INFO: Random stat is 54146
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 22.6%
# Estimated detectable doublet fraction = 75.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.9%
# Elapsed time: 11.8 seconds
# INFO: summation doublets!
# 0.08001561280249805
# INFO: Random stat is 47877
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 20.5%
# Estimated detectable doublet fraction = 75.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 27.2%
# Elapsed time: 18.8 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 55140
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 15.2%
# Estimated detectable doublet fraction = 62.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.5%
# Elapsed time: 14.1 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 97287
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 11.5%
# Estimated detectable doublet fraction = 47.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.5%
# Elapsed time: 23.3 seconds
# INFO: summation doublets!
# 0.08000891464229998
# INFO: Random stat is 89792
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 9.4%
# Estimated detectable doublet fraction = 38.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 24.5%
# Elapsed time: 27.5 seconds
# INFO: summation doublets!
# 0.08001070377308
# INFO: Random stat is 76223
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 15.9%
# Estimated detectable doublet fraction = 55.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.7%
# Elapsed time: 20.5 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.0800113895216401
# INFO: Random stat is 10545
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 4.8%
# Estimated detectable doublet fraction = 52.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 9.2%
# Elapsed time: 16.5 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 95917
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 5.1%
# Estimated detectable doublet fraction = 57.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 8.8%
# Elapsed time: 23.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 47595
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 5.7%
# Estimated detectable doublet fraction = 59.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 9.5%
# Elapsed time: 17.6 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 30863
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 5.5%
# Estimated detectable doublet fraction = 63.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 8.8%
# Elapsed time: 16.9 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 85812
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 1.7%
# Estimated detectable doublet fraction = 12.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 13.8%
# Elapsed time: 11.2 seconds
# INFO: summation doublets!
# 0.08000315905860053
# INFO: Random stat is 845
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.05
# Detected doublet rate = 97.7%
# Estimated detectable doublet fraction = 99.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 97.8%
# Elapsed time: 55.7 seconds
# INFO: summation doublets!
# 0.08000418322526669
# INFO: Random stat is 44327
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 39.0 seconds
# INFO: summation doublets!
# 0.08000778664590227
# INFO: Random stat is 74349
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 2.8%
# Estimated detectable doublet fraction = 28.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 9.9%
# Elapsed time: 26.7 seconds
# INFO: summation doublets!
# 0.08001207729468598
# INFO: Random stat is 25271
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.10
# Detected doublet rate = 97.8%
# Estimated detectable doublet fraction = 99.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 97.9%
# Elapsed time: 19.1 seconds
# INFO: summation doublets!
# 0.08000456516776991
# INFO: Random stat is 38059
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 6.4%
# Estimated detectable doublet fraction = 46.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 14.0%
# Elapsed time: 38.8 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 43111
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 5.0%
# Estimated detectable doublet fraction = 41.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 12.2%
# Elapsed time: 11.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 92891
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 23.2%
# Estimated detectable doublet fraction = 72.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 32.0%
# Elapsed time: 12.6 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 55222
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 3.2%
# Estimated detectable doublet fraction = 28.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 11.2%
# Elapsed time: 13.6 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 69562
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 4.5%
# Estimated detectable doublet fraction = 32.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 14.0%
# Elapsed time: 12.7 seconds
# INFO: summation doublets!
# 0.08000396550014871
# INFO: Random stat is 16319
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 6.4%
# Estimated detectable doublet fraction = 37.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.1%
# Elapsed time: 41.4 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 29085
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 9.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 14.6%
# Elapsed time: 7.3 seconds
# INFO: summation doublets!
# 0.08
# INFO: Random stat is 98827
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 25.3%
# Estimated detectable doublet fraction = 69.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 36.6%
# Elapsed time: 16.0 seconds
# INFO: summation doublets!
# 0.08000621407487961
# INFO: Random stat is 91847
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 8.6%
# Estimated detectable doublet fraction = 53.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 16.3%
# Elapsed time: 31.9 seconds
# INFO: summation doublets!
# 0.0800561797752809
# INFO: Random stat is 77251
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.74
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 4.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 38.6%
# Elapsed time: 5.6 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.08001397624039133
# INFO: Random stat is 42681
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 12.9%
# Estimated detectable doublet fraction = 38.7%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 33.3%
# Elapsed time: 19.3 seconds
# INFO: summation doublets!
# 0.08003369839932603
# INFO: Random stat is 81277
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 8.5%
# Estimated detectable doublet fraction = 29.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.1%
# Elapsed time: 7.4 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.080078125
# INFO: Random stat is 34951
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 8.6%
# Estimated detectable doublet fraction = 57.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.0%
# Elapsed time: 6.6 seconds
# INFO: summation doublets!
# 0.08015267175572519
# INFO: Random stat is 18699
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 4.6%
# Estimated detectable doublet fraction = 48.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 9.5%
# Elapsed time: 7.2 seconds
# /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.08010335917312661
# INFO: Random stat is 55425
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 4.9%
# Estimated detectable doublet fraction = 49.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 10.0%
# Elapsed time: 6.6 seconds
