# %%
import matplotlib.pyplot as plt
from scrublet_util import *
import os
import re

# %%
################################
#                              #
#       Input Parameters       #
#                              #
################################
root_dir = "/projects/p31666/zzhang/doublet-bchmk/data/fatemap_data"
out_dir = "/projects/p31666/zzhang/doublet-bchmk/final_sum"
save_root = "/projects/b1042/GoyalLab/zzhang/doublet_objects_sum/scrublet"
METHOD_ID = "scrublet"
root_bchmk_dataset = "/projects/p31666/zzhang/doublet-bchmk/data/bchmk_paper_real_data"
num_test = 1
doublet_rates_to_test = [0.05, 0.08, 0.1, 0.15, 0.2, 0.25]
ACT_DBL = 0.15


################################
#                              #
#             Main             #
#                              #
################################

def main(root_dir, METHOD_ID, out_dir):
    out_dfs = []
    out_stats = []
    
    all_detection_rates_file = os.path.join(out_dir, METHOD_ID, "stats", "all_detection_rates_{}.tsv".format(ACT_DBL))
    all_datasets_dirs = [os.path.join(root_dir, x) for x in next(os.walk(root_dir))[1]]
    for expected_doublet_rate in doublet_rates_to_test:
        print("INFO: Currently testing expected doublet rate:{}, actual doublet rate:{}".
              format(str(expected_doublet_rate), str(ACT_DBL)))
        for cur_dataset_dir in all_datasets_dirs:
            cur_out_df = run_scrublet_on_dataset(cur_dataset_dir, METHOD_ID, num_to_test=num_test,
                                                 exp_dbl=expected_doublet_rate, act_dbl=ACT_DBL, save_root = save_root)
            out_dfs.append(cur_out_df)
            cur_out_df["dbl_exp"] = expected_doublet_rate
            cur_out_df["dbl_act"] = ACT_DBL

    all_df = pd.concat(out_dfs)
    all_df.to_csv(all_detection_rates_file, sep="\t", index=False)
    return True


if __name__ == "__main__":
    main(root_dir, METHOD_ID, out_dir)
# Out:
# INFO: Currently testing expected doublet rate:0.05, actual doublet rate:0.15
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.15003240440699936
# INFO: Random stat is 33292
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 36.4%
# Elapsed time: 9.9 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 43019
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 16.1 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 65687
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 2.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.5%
# Elapsed time: 4.0 seconds
# INFO: summation doublets!
# 0.15002918855808522
# INFO: Random stat is 71633
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.3%
# Elapsed time: 6.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 24842
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.2%
# Elapsed time: 16.1 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 16558
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.5%
# Elapsed time: 19.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 95782
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 37.5%
# Elapsed time: 15.6 seconds
# INFO: summation doublets!
# 0.1500169319336268
# INFO: Random stat is 16878
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 14.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.1500089397461112
# INFO: Random stat is 75075
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 15.3 seconds
# INFO: summation doublets!
# 0.1500342543959808
# INFO: Random stat is 99369
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.5%
# Elapsed time: 14.8 seconds
# INFO: summation doublets!
# 0.15002143163309045
# INFO: Random stat is 49600
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.9%
# Elapsed time: 14.7 seconds
# INFO: summation doublets!
# 0.15003178639542275
# INFO: Random stat is 30617
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.4%
# Elapsed time: 8.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/watermelon
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 31974
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.9%
# Elapsed time: 15.1 seconds
# INFO: summation doublets!
# 0.15002219263204616
# INFO: Random stat is 46776
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.8%
# Elapsed time: 14.9 seconds
# INFO: summation doublets!
# 0.15002249212775529
# INFO: Random stat is 89747
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.6 seconds
# INFO: summation doublets!
# 0.1500085426277123
# INFO: Random stat is 46019
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 19.1 seconds
# INFO: summation doublets!
# 0.1500103455410718
# INFO: Random stat is 8483
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 15.7 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 63613
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.8%
# Elapsed time: 17.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/Biorxiv
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 74578
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 4.1%
# Estimated detectable doublet fraction = 5.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 80.0%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.15007215007215008
# INFO: Random stat is 44885
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 150.0%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 26809
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 2.8%
# Estimated detectable doublet fraction = 8.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.9%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.15009041591320071
# INFO: Random stat is 28403
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.21
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 2.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 100.0%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.15012722646310434
# INFO: Random stat is 49916
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 4.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.5%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.1500646830530401
# INFO: Random stat is 46873
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 1.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 34.8%
# Elapsed time: 2.4 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM02
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 60385
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 14.6 seconds
# INFO: summation doublets!
# 0.15002447381302006
# INFO: Random stat is 82033
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 10.6 seconds
# INFO: summation doublets!
# 0.1500201369311317
# INFO: Random stat is 96411
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 11.5 seconds
# INFO: summation doublets!
# 0.15000797066794197
# INFO: Random stat is 4077
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 14.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/cellTag
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 33273
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 4.2 seconds
# INFO: summation doublets!
# 0.1500144801621778
# INFO: Random stat is 96753
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 7.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_reads
# INFO: summation doublets!
# 0.15010570824524314
# INFO: Random stat is 83701
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 8.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 12.7%
# Elapsed time: 4.6 seconds
# INFO: summation doublets!
# 0.15018315018315018
# INFO: Random stat is 80785
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 8.2%
# Estimated detectable doublet fraction = 53.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 15.4%
# Elapsed time: 1.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM03
# INFO: summation doublets!
# 0.15001221597849987
# INFO: Random stat is 65284
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 11.3 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 32383
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 7.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/LARRY
# INFO: summation doublets!
# 0.15001740341106856
# INFO: Random stat is 14756
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.10
# Detected doublet rate = 13.8%
# Estimated detectable doublet fraction = 62.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.1%
# Elapsed time: 5.8 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 84454
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.7%
# Elapsed time: 3.2 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 46069
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.3%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.15002219263204616
# INFO: Random stat is 83019
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 6.7%
# Elapsed time: 3.9 seconds
# INFO: summation doublets!
# 0.15011286681715574
# INFO: Random stat is 41650
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.0%
# Elapsed time: 4.0 seconds
# INFO: summation doublets!
# 0.15015015015015015
# INFO: Random stat is 65908
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 4.5%
# Estimated detectable doublet fraction = 9.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 46.9%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.15017064846416384
# INFO: Random stat is 33141
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 1.4%
# Estimated detectable doublet fraction = 2.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 64.0%
# Elapsed time: 3.9 seconds
# INFO: summation doublets!
# 0.15003326679973386
# INFO: Random stat is 72857
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 5.8 seconds
# INFO: summation doublets!
# 0.15001277791975468
# INFO: Random stat is 10391
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.2%
# Elapsed time: 4.9 seconds
# INFO: summation doublets!
# 0.15002411963338158
# INFO: Random stat is 85561
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 18.2%
# Elapsed time: 2.2 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 89689
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.8%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.15004336513443192
# INFO: Random stat is 21749
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 75.0%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.15027322404371585
# INFO: Random stat is 40377
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 2.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 75.0%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.15022421524663676
# INFO: Random stat is 9608
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 47.1%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.15021459227467812
# INFO: Random stat is 31855
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.1%
# Elapsed time: 0.9 seconds
# INFO: summation doublets!
# 0.150093808630394
# INFO: Random stat is 49259
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 40.0%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.15015479876160992
# INFO: Random stat is 72358
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.0%
# Elapsed time: 1.2 seconds
# INFO: summation doublets!
# 0.15012106537530268
# INFO: Random stat is 19793
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 2.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 44.4%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 92326
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 200.0%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.15019011406844107
# INFO: Random stat is 93162
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 4.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 37.2%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 71911
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 12.2%
# Estimated detectable doublet fraction = 55.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.0%
# Elapsed time: 4.1 seconds
# INFO: summation doublets!
# 0.15003043213633596
# INFO: Random stat is 64592
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 10.5%
# Elapsed time: 3.8 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 45498
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 60.0%
# Elapsed time: 1.6 seconds
# INFO: summation doublets!
# 0.15004055150040552
# INFO: Random stat is 41271
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 47.6%
# Elapsed time: 2.5 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 58325
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 3.6 seconds
# INFO: summation doublets!
# 0.15010141987829614
# INFO: Random stat is 95543
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 3.4%
# Estimated detectable doublet fraction = 5.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 59.6%
# Elapsed time: 0.7 seconds
# INFO: summation doublets!
# 0.15003441156228492
# INFO: Random stat is 58661
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 41.4%
# Elapsed time: 3.7 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 74169
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 4.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 11.8%
# Elapsed time: 2.3 seconds
# INFO: summation doublets!
# 0.150093808630394
# INFO: Random stat is 30114
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 30.0%
# Elapsed time: 1.0 seconds
# INFO: summation doublets!
# 0.1500453309156845
# INFO: Random stat is 88743
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 3.7 seconds
# INFO: summation doublets!
# 0.15020576131687244
# INFO: Random stat is 64697
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.27
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 3.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 25.8%
# Elapsed time: 1.2 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 77546
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.6%
# Elapsed time: 3.5 seconds
# INFO: summation doublets!
# 0.15002072109407377
# INFO: Random stat is 81809
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.09
# Detected doublet rate = 18.6%
# Estimated detectable doublet fraction = 67.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 27.4%
# Elapsed time: 4.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.15003668378576668
# INFO: Random stat is 89272
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.8%
# Elapsed time: 3.1 seconds
# INFO: summation doublets!
# 0.15000872143729285
# INFO: Random stat is 31233
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 8.6 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 2599
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 7.4%
# Elapsed time: 7.6 seconds
# INFO: summation doublets!
# 0.1500285225328009
# INFO: Random stat is 55507
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.0%
# Elapsed time: 5.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.1500302480338778
# INFO: Random stat is 48522
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 7.8%
# Estimated detectable doublet fraction = 53.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.7%
# Elapsed time: 6.3 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 430
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 9.0%
# Estimated detectable doublet fraction = 60.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.8%
# Elapsed time: 13.1 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 35460
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.10
# Detected doublet rate = 10.8%
# Estimated detectable doublet fraction = 64.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 16.6%
# Elapsed time: 3.4 seconds
# INFO: summation doublets!
# 0.15001556178026768
# INFO: Random stat is 23032
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 9.2%
# Estimated detectable doublet fraction = 62.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.7%
# Elapsed time: 6.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.15005476451259583
# INFO: Random stat is 11078
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 2.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 1.3 seconds
# INFO: summation doublets!
# 0.15000841325929665
# INFO: Random stat is 70673
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 28.6%
# Elapsed time: 33.5 seconds
# INFO: summation doublets!
# 0.15001112842198977
# INFO: Random stat is 42627
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.63
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 25.6 seconds
# INFO: summation doublets!
# 0.15002072109407377
# INFO: Random stat is 28226
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.1 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 7616
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 33.3%
# Elapsed time: 6.5 seconds
# INFO: summation doublets!
# 0.15000607312036923
# INFO: Random stat is 38586
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 9.5%
# Elapsed time: 23.0 seconds
# INFO: summation doublets!
# 0.1500777604976672
# INFO: Random stat is 6761
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 3.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 22.0%
# Elapsed time: 2.0 seconds
# INFO: summation doublets!
# 0.15014577259475217
# INFO: Random stat is 80939
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 7.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 20.8%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 64620
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 3.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 13.5%
# Elapsed time: 1.5 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 16951
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 1.1%
# Estimated detectable doublet fraction = 1.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 62.9%
# Elapsed time: 1.4 seconds
# INFO: summation doublets!
# 0.15000527815897816
# INFO: Random stat is 18279
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Elapsed time: 25.4 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 38604
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 4.5%
# Estimated detectable doublet fraction = 13.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 35.1%
# Elapsed time: 0.8 seconds
# INFO: summation doublets!
# 0.15007656967840735
# INFO: Random stat is 55299
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 3.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 4.5%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.15001653986106517
# INFO: Random stat is 62231
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 14.8%
# Elapsed time: 15.9 seconds
# INFO: summation doublets!
# 0.15015015015015015
# INFO: Random stat is 96046
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.30
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 2.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 38.7%
# Elapsed time: 1.2 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.1500185666542889
# INFO: Random stat is 17856
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 23.5%
# Elapsed time: 5.5 seconds
# INFO: summation doublets!
# 0.1500449236298293
# INFO: Random stat is 2388
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 29.6%
# Elapsed time: 3.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
# INFO: summation doublets!
# 0.15020576131687244
# INFO: Random stat is 44836
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 10.1%
# Estimated detectable doublet fraction = 51.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.6%
# Elapsed time: 1.9 seconds
# INFO: summation doublets!
# 0.15040650406504066
# INFO: Random stat is 13320
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 19.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 8.2%
# Elapsed time: 3.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3
# INFO: summation doublets!
# 0.15027322404371585
# INFO: Random stat is 88632
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.10
# Detected doublet rate = 11.7%
# Estimated detectable doublet fraction = 59.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 19.7%
# Elapsed time: 2.0 seconds
# INFO: Currently testing expected doublet rate:0.08, actual doublet rate:0.15
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM04
# INFO: summation doublets!
# 0.15003240440699936
# INFO: Random stat is 62259
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 44.4%
# Elapsed time: 5.9 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 84
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 25.0%
# Elapsed time: 13.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/non_cancer
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 22697
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 1.9%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 20.8%
# Elapsed time: 2.9 seconds
# INFO: summation doublets!
# 0.15002918855808522
# INFO: Random stat is 7239
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 33.3%
# Elapsed time: 2.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM05
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 45620
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 13.6%
# Elapsed time: 12.3 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 74499
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.3 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM06
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 80639
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 37.5%
# Elapsed time: 11.2 seconds
# INFO: summation doublets!
# 0.1500169319336268
# INFO: Random stat is 33520
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 18.7%
# Elapsed time: 14.0 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM01
# INFO: summation doublets!
# 0.1500089397461112
# INFO: Random stat is 66507
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.69
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 0.0%
# Elapsed time: 16.5 seconds
# INFO: summation doublets!
# 0.1500342543959808
# INFO: Random stat is 76766
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.65
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 18.2%
# Elapsed time: 15.6 seconds
# INFO: summation doublets!
# 0.15002143163309045
# INFO: Random stat is 13569
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.65
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 8.0%
# ...
# Elapsed time: 10.8 seconds
# INFO: summation doublets!
# 0.15003441156228492
# INFO: Random stat is 67159
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 32.7%
# Estimated detectable doublet fraction = 53.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 60.7%
# Elapsed time: 18.3 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 3333
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 15.5%
# Estimated detectable doublet fraction = 51.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 30.2%
# Elapsed time: 15.7 seconds
# INFO: summation doublets!
# 0.150093808630394
# INFO: Random stat is 57276
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.78
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 1.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 40.0%
# Elapsed time: 8.5 seconds
# INFO: summation doublets!
# 0.1500453309156845
# INFO: Random stat is 77285
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 9.1%
# Estimated detectable doublet fraction = 36.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 25.3%
# Elapsed time: 19.0 seconds
# INFO: summation doublets!
# 0.15020576131687244
# INFO: Random stat is 48156
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.70
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 4.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 19.0%
# Elapsed time: 5.1 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 2839
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.80
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 21.4%
# Elapsed time: 23.5 seconds
# INFO: summation doublets!
# 0.15002072109407377
# INFO: Random stat is 50158
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 70.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 28.2%
# Elapsed time: 23.7 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/ClonMapper
# INFO: summation doublets!
# 0.15003668378576668
# INFO: Random stat is 28609
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 18.3%
# Estimated detectable doublet fraction = 62.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 29.1%
# Elapsed time: 18.6 seconds
# INFO: summation doublets!
# 0.15000872143729285
# INFO: Random stat is 9306
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 66.4%
# Estimated detectable doublet fraction = 93.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 71.0%
# Elapsed time: 23.6 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 35269
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 17.0%
# Estimated detectable doublet fraction = 53.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 32.0%
# Elapsed time: 26.9 seconds
# INFO: summation doublets!
# 0.1500285225328009
# INFO: Random stat is 14440
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 12.7%
# Estimated detectable doublet fraction = 49.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 25.9%
# Elapsed time: 18.5 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/TREX
# INFO: summation doublets!
# 0.1500302480338778
# INFO: Random stat is 18619
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 9.8%
# Estimated detectable doublet fraction = 58.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 16.8%
# Elapsed time: 18.2 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 67935
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 12.5%
# Estimated detectable doublet fraction = 73.1%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.1%
# Elapsed time: 28.3 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 10122
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 12.4%
# Estimated detectable doublet fraction = 71.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.3%
# Elapsed time: 13.7 seconds
# INFO: summation doublets!
# 0.15001556178026768
# INFO: Random stat is 27750
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 30.2%
# Estimated detectable doublet fraction = 89.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 33.5%
# Elapsed time: 17.6 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/SPLINTR
# INFO: summation doublets!
# 0.15005476451259583
# INFO: Random stat is 82035
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 4.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 20.0%
# Elapsed time: 11.2 seconds
# INFO: summation doublets!
# 0.15000841325929665
# INFO: Random stat is 12305
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.03
# Detected doublet rate = 98.6%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 98.6%
# Elapsed time: 57.4 seconds
# INFO: summation doublets!
# 0.15001112842198977
# INFO: Random stat is 65768
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 4.6%
# Estimated detectable doublet fraction = 27.9%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 16.4%
# Elapsed time: 43.8 seconds
# INFO: summation doublets!
# 0.15002072109407377
# INFO: Random stat is 59485
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 5.3%
# Estimated detectable doublet fraction = 34.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 15.2%
# Elapsed time: 24.5 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 90985
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.05
# Detected doublet rate = 99.8%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 99.8%
# Elapsed time: 18.3 seconds
# INFO: summation doublets!
# 0.15000607312036923
# INFO: Random stat is 68339
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 6.8%
# Estimated detectable doublet fraction = 39.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.3%
# Elapsed time: 38.8 seconds
# INFO: summation doublets!
# 0.1500777604976672
# INFO: Random stat is 80587
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 13.6%
# Estimated detectable doublet fraction = 57.3%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 23.8%
# Elapsed time: 11.4 seconds
# INFO: summation doublets!
# 0.15014577259475217
# INFO: Random stat is 94174
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 9.6%
# Estimated detectable doublet fraction = 50.4%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 19.1%
# Elapsed time: 12.7 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 33042
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 3.6%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 17.1%
# Elapsed time: 5.3 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 92848
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 9.5%
# Estimated detectable doublet fraction = 46.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 20.6%
# Elapsed time: 9.9 seconds
# INFO: summation doublets!
# 0.15000527815897816
# INFO: Random stat is 58357
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 14.8%
# Estimated detectable doublet fraction = 57.2%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.0%
# Elapsed time: 39.9 seconds
# INFO: summation doublets!
# 0.15
# INFO: Random stat is 52479
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 4.1%
# Estimated detectable doublet fraction = 12.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 32.7%
# Elapsed time: 1.1 seconds
# INFO: summation doublets!
# 0.15007656967840735
# INFO: Random stat is 5939
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.73
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.5%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 6.1%
# Elapsed time: 5.8 seconds
# INFO: summation doublets!
# 0.15001653986106517
# INFO: Random stat is 50482
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 29.2 seconds
# INFO: summation doublets!
# 0.15015015015015015
# INFO: Random stat is 69701
# Preprocessing...
# /home/zzj4347/softwares/anaconda3/envs/doublet-bchmk/lib/python3.7/site-packages/scrublet/helper_functions.py:241: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 32.6%
# Estimated detectable doublet fraction = 76.8%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 42.4%
# Elapsed time: 8.9 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/FM08
# INFO: summation doublets!
# 0.1500185666542889
# INFO: Random stat is 22587
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 13.4%
# Estimated detectable doublet fraction = 39.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 34.5%
# Elapsed time: 15.0 seconds
# INFO: summation doublets!
# 0.1500449236298293
# INFO: Random stat is 74619
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 7.3%
# Estimated detectable doublet fraction = 28.0%
# Overall doublet rate:
# 	Expected   = 25.0%
# 	Estimated  = 26.0%
# Elapsed time: 11.8 seconds
# Working on dataset: /projects/p31666/zzhang/doublet-bchmk/data/fatemap_data/smartseq3_umis
